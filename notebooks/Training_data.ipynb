# %% [markdown]
# # Examine available LULC training data
#
# Key considerations:
# * Spatial distribution, especially in SIDS
# * Class distribution
# * Temporal coverage
# * Quality and confidence
# * Trends in agreement with LULC datasets
